# %%
import numpy as np
import pandas as pd

# %%
train_twitter = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CSV/dataset.csv", encoding='latin-1')

# %%
train_twitter
# Out:
#        ItemID  Sentiment                                      SentimentText
# 0           1          0                       is so sad for my APL frie...
# 1           2          0                     I missed the New Moon trail...
# 2           3          1                            omg its already 7:30 :O
# 3           4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5          0           i think mi bf is cheating on me!!!   ...
# ...       ...        ...                                                ...
# 99984   99996          0  @Cupcake  seems like a repeating problem   hop...
# 99985   99997          1  @cupcake__ arrrr we both replied to each other...
# 99986   99998          0                     @CuPcAkE_2120 ya i thought so
# 99987   99999          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99988  100000          1                    @cupcake_kayla haha yes you do
#
# [99989 rows x 3 columns]

# %%
random_indexs = np.random.randint(1,len(train_twitter),20).tolist()
train_twitter["SentimentText"][random_indexs]
# Out:
# 51904    @AuntSay I miss him.  I think I might be turni...
# 81010                                    @charlottespeech
# 53854                @augustmajor ! my teeny tiny fwend !
# 77239    @catchthizTEE aight mos def if you get to my t...
# 99988                      @cupcake_kayla haha yes you do
# 87049    @autria  HEHEHE SORRY !!  ) I will meditate la...
# 93051    @Chrissymarsh Omg I was just about to text you...
# 61401    @billbeckett http://twitpic.com/4p2gn - Wow ! ...
# 54976    @banjoist123 may I ask what bluegrass means? S...
# 92161    @chriscowdery ooh lucky! I just missed another...
# 74130    @car0lyn You forgot to specify a target!  http...
# 94974    @CQuin just found a load of replies I've not s...
# 1264              awesome day! soooooooooooooo happy &lt;3
# 29595    @Adam_WR Haha yeah! But he's refusing to play ...
# 96941    @clumsyharmonica sorry for not making it to yo...
# 39665    @AlyxxDione I miss my red hair too  I'm all bl...
# 32406    @AliceCullen4 Indeed (: Sorry huni.. i have to...
# 48957     @arianna_skye my pleasure ...I had a great time
# 65801    @brian_littrell Hey! finally a tweet!! I've be...
# 15211         .@OHT later this year...   #googlewave #wave
# Name: SentimentText, dtype: object

# %%
import re
tweets_text = train_twitter.SentimentText.str.cat()
emos = set(re.findall(r" ([xX:;][-']?.) ",tweets_text))
emos_count = []
for emo in emos:
    emos_count.append((tweets_text.count(emo), emo))
sorted(emos_count,reverse=True)
# Out:
# [(3281, ':/'),
#  (2874, 'x '),
#  (2626, ': '),
#  (1339, 'x@'),
#  (1214, 'xx'),
#  (1162, 'xa'),
#  (984, ';3'),
#  (887, 'xp'),
#  (842, 'xo'),
#  (713, ';)'),
#  (483, 'xe'),
#  (431, ';I'),
#  (353, ';.'),
#  (254, 'xD'),
#  (251, 'x.'),
#  (245, '::'),
#  (234, 'X '),
#  (217, ';t'),
#  (209, ';s'),
#  (185, ':O'),
#  (176, ':3'),
#  (166, ';D'),
#  (159, ":'"),
#  (157, 'XD'),
#  (146, 'x3'),
#  (142, ':p'),
#  (126, ":'("),
#  (118, ':@'),
#  (117, 'xh'),
#  (117, ':S'),
#  (109, 'xm'),
#  (104, ';p'),
#  (104, ';-)'),
#  (92, ':|'),
#  (91, 'x,'),
#  (89, ';P'),
#  (76, 'xd'),
#  (75, ';o'),
#  (75, ';d'),
#  (71, ':o'),
#  (65, 'XX'),
#  (63, ':L'),
#  (59, 'Xx'),
#  (59, ':1'),
#  (58, ':]'),
#  (57, ':s'),
#  (56, ':0'),
#  (54, 'XO'),
#  (44, ';;'),
#  (43, ';('),
#  (38, ':-D'),
#  (37, 'xk'),
#  (36, 'XT'),
#  (35, 'x?'),
#  (35, 'x)'),
#  (34, 'x2'),
#  (33, ';/'),
#  (32, 'x:'),
#  (32, ':\\'),
#  (31, 'x-'),
#  (27, 'Xo'),
#  (27, 'XP'),
#  (27, ':-/'),
#  (26, ':-P'),
#  (25, ':*'),
#  (23, 'xX'),
#  (22, ":')"),
#  (17, 'xP'),
#  (16, ':['),
#  (16, ':-p'),
#  (14, 'x]'),
#  (14, 'XM'),
#  (13, ':-O'),
#  (12, 'x('),
#  (12, 'X1'),
#  (12, ':x'),
#  (11, 'XS'),
#  (11, ':l'),
#  (10, 'x*'),
#  (10, 'X.'),
#  (10, ':b'),
#  (10, ':T'),
#  (9, ';]'),
#  (9, ':I'),
#  (8, ':C'),
#  (7, ';-('),
#  (7, ':-|'),
#  (6, 'X,'),
#  (6, ':-o'),
#  (6, ':-\\'),
#  (6, ':-*'),
#  (6, ':$'),
#  (5, 'XL'),
#  (5, ':d'),
#  (5, ':X'),
#  (5, ':H'),
#  (5, ':?'),
#  (5, ':-S'),
#  (4, ';-D'),
#  (3, ':Z'),
#  (3, ':E'),
#  (3, ':-s'),
#  (3, ':-['),
#  (3, ':-X'),
#  (2, 'X5'),
#  (2, 'X-('),
#  (2, "X's"),
#  (2, ';-;'),
#  (2, ':}'),
#  (2, ':D'),
#  (2, ':;'),
#  (2, ":'D"),
#  (1, 'x|'),
#  (1, "x'd"),
#  (1, "x'D"),
#  (1, ';-|'),
#  (1, ';-/'),
#  (1, ':-x'),
#  (1, ':-h'),
#  (1, ':-]'),
#  (1, ':-W'),
#  (1, ':-$'),
#  (1, ':('),
#  (1, ":'[")]

# %%
HAPPY_EMO = r" ([xX;:]-?[dD)]|:-?[\)]|[;:][pP]) "
SAD_EMO = r" (:'?[/|\(]) "
print("Happy emoticons:", set(re.findall(HAPPY_EMO, tweets_text)))
print("Sad emoticons:", set(re.findall(SAD_EMO, tweets_text)))
# Out:
# Happy emoticons: {':p', ';-)', ';p', ':D', ':d', 'XD', ':-D', ';-D', ';d', 'xD', 'x)', ';P', ';)', 'xd', ';D'}
# Sad emoticons: {':|', ':(', ":'(", ':/'}

# %%
import re
tweets= train_twitter.SentimentText.str.cat()
emo_find = set(re.findall(r"([:@$][-'xX]?.;)",tweets_text))
emo_count = []
for emo in emo_find:
    emos_count.append((tweets_text.count(emo), emo))
sorted(emos_count)
# Out:
# [(1, ":'["),
#  (1, ':('),
#  (1, ':-$'),
#  (1, ':-W'),
#  (1, ':-]'),
#  (1, ':-h'),
#  (1, ':-x'),
#  (1, ':/;'),
#  (1, ':G;'),
#  (1, ':|;'),
#  (1, ';-/'),
#  (1, ';-|'),
#  (1, "x'D"),
#  (1, "x'd"),
#  (1, 'x|'),
#  (2, ":'D"),
#  (2, ':;'),
#  (2, ':D'),
#  (2, ':}'),
#  (2, ';-;'),
#  (2, "X's"),
#  (2, 'X-('),
#  (2, 'X5'),
#  (3, ':-X'),
#  (3, ':-['),
#  (3, ':-s'),
#  (3, ':E'),
#  (3, ':Z'),
#  (4, ';-D'),
#  (5, ':-S'),
#  (5, ':?'),
#  (5, ':H'),
#  (5, ':X'),
#  (5, ':d'),
#  (5, 'XL'),
#  (6, ':$'),
#  (6, ':-*'),
#  (6, ':-\\'),
#  (6, ':-o'),
#  (6, 'X,'),
#  (7, ':-|'),
#  (7, ';-('),
#  (8, ':C'),
#  (9, ':I'),
#  (9, ';]'),
#  (10, ':T'),
#  (10, ':b'),
#  (10, 'X.'),
#  (10, 'x*'),
#  (11, ':l'),
#  (11, 'XS'),
#  (12, ':x'),
#  (12, 'X1'),
#  (12, 'x('),
#  (13, ':-O'),
#  (14, 'XM'),
#  (14, 'x]'),
#  (16, ':-p'),
#  (16, ':['),
#  (17, 'xP'),
#  (22, ":')"),
#  (23, 'xX'),
#  (25, ':*'),
#  (26, ':-P'),
#  (27, ':-/'),
#  (27, 'XP'),
#  (27, 'Xo'),
#  (31, 'x-'),
#  (32, ':\\'),
#  (32, 'x:'),
#  (33, ';/'),
#  (34, 'x2'),
#  (35, 'x)'),
#  (35, 'x?'),
#  (36, 'XT'),
#  (37, 'xk'),
#  (38, ':-D'),
#  (43, ';('),
#  (44, ';;'),
#  (54, 'XO'),
#  (56, ':0'),
#  (57, ':s'),
#  (58, ':]'),
#  (59, ':1'),
#  (59, 'Xx'),
#  (63, ':L'),
#  (65, 'XX'),
#  (71, ':o'),
#  (75, ';d'),
#  (75, ';o'),
#  (76, 'xd'),
#  (89, ';P'),
#  (91, 'x,'),
#  (92, ':|'),
#  (104, ';-)'),
#  (104, ';p'),
#  (109, 'xm'),
#  (117, ':S'),
#  (117, 'xh'),
#  (118, ':@'),
#  (126, ":'("),
#  (142, ':p'),
#  (146, 'x3'),
#  (157, 'XD'),
#  (159, ":'"),
#  (166, ';D'),
#  (176, ':3'),
#  (185, ':O'),
#  (209, ';s'),
#  (217, ';t'),
#  (234, 'X '),
#  (245, '::'),
#  (251, 'x.'),
#  (254, 'xD'),
#  (353, ';.'),
#  (431, ';I'),
#  (483, 'xe'),
#  (713, ';)'),
#  (842, 'xo'),
#  (887, 'xp'),
#  (984, ';3'),
#  (1162, 'xa'),
#  (1214, 'xx'),
#  (1339, 'x@'),
#  (2626, ': '),
#  (2874, 'x '),
#  (3281, ':/')]

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
def common_Words(text):
    tokens = word_tokenize(text)
    frequency = nltk.FreqDist(tokens)
    print("This dataset has %d different words" % len(set(tokens)))
    return sorted(frequency,key=frequency.__getitem__)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
common_Words(train_twitter.SentimentText.str.cat())[:100]
# Out:
# This dataset has 134028 different words
# ['APL',
#  'Omgaga',
#  'CRy',
#  'suposed',
#  'Juuuuuuuuuuuuuuuuussssst',
#  '112-102',
#  'awhhe',
#  '//myloc.me/27HX',
#  'Semisonic',
#  'shaunamanu',
#  'wompppp',
#  'wompp',
#  '-Sad',
#  '*lays',
#  'position*',
#  'Hospitol',
#  'Tourny',
#  'Re-Ripped',
#  'BoRinG',
#  'Feeeling',
#  'ACL',
#  'Meat',
#  '//bit.ly/15SSCI',
#  'horsie',
#  'Wardrobe',
#  'Waiit',
#  'relievers',
#  'scolding',
#  'Fightiin',
#  'Wiit',
#  '//tumblr.com/xcn21w6o7',
#  '*enough',
#  'said*',
#  'CORNELL',
#  'ginaaa',
#  'Muslims',
#  'properly..',
#  'rupturerapture',
#  'baddest',
#  'eveer',
#  'helio',
#  '//bit.ly/ZoxZC',
#  '//bit.ly/azFwv',
#  'quilting',
#  'leysh',
#  't9ar5',
#  '..=-',
#  'foreverr',
#  '//tumblr.com/xkh1z19us',
#  'Manuel',
#  'anyonefeeling',
#  'kezbat',
#  'nebody',
#  'slope..and',
#  'wall..Math',
#  "'cough",
#  '2009..hope',
#  'Jin',
#  'Hom',
#  'Fr',
#  'TDa',
#  'Cried',
#  'is..and',
#  'want..',
#  'Zahra',
#  '//tumblr.com/xwp1yxhi6',
#  'momacita',
#  'pavel',
#  'Tigersfan',
#  'Safina',
#  'ood',
#  'sannesias',
#  '//tumblr.com/xv31s2pi8',
#  'gigi4462',
#  'overdosed',
#  'haterade',
#  'throwbie',
#  'Editors',
#  'Heathers',
#  'Winona4ever',
#  'b.b',
#  'trae',
#  'baithing',
#  'Wove',
#  'Tombre',
#  '//is.gd/13be0',
#  'Rishabh',
#  'waahhh',
#  'stitched',
#  'whatï¿½s',
#  '//tumblr.com/xsg1m3ufn',
#  '//www.imediaconnection.com/content/23465.asp',
#  'Kristis',
#  'mmmaybe',
#  'FRANK',
#  'LAMPARD',
#  '//tumblr.com/xaj24dkly',
#  '12*23*2007',
#  'poemsunder140',
#  '.started']

# %%
from nltk.corpus import stopwords

nltk.download("stopwords")

mw = common_Words(train_twitter.SentimentText.str.cat())
most_words = []
for w in mw:
    if len(most_words) == 1000:
        break
    if w in stopwords.words("english"):
        continue
    else:
        most_words.append(w)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# This dataset has 134028 different words

# %%
sorted(most_words)
# Out:
# ["''Love",
#  "'16",
#  "'FML",
#  "'Pi",
#  "'Rat",
#  "'churchgirl",
#  "'cough",
#  "'new",
#  "'nother",
#  "'value",
#  '***********',
#  '*BeautifulyLost-',
#  '*Blushes*',
#  '*cancels',
#  '*eek*',
#  '*enough',
#  '*exited*',
#  '*hummin*',
#  '*ill*',
#  '*lays',
#  '*old',
#  '*~Free',
#  '-4',
#  '-Sad',
#  '-as',
#  '-dammit',
#  '-elf',
#  '-pressure',
#  '..=-',
#  '..doing',
#  '..frustrated',
#  '..omg',
#  '..pick',
#  '..sniffles',
#  '..thinking',
#  '..tlk',
#  '..y',
#  '.EXE',
#  '.PPT',
#  '.TXT',
#  '.bueno',
#  '.imu',
#  '.moving',
#  '.okay',
#  '.sniff',
#  '.started',
#  '//3',
#  '//bit.ly/10H4ne',
#  '//bit.ly/10o8LW',
#  '//bit.ly/11zyzl',
#  '//bit.ly/12nP1H',
#  '//bit.ly/15SSCI',
#  '//bit.ly/15TpJC',
#  '//bit.ly/16ZZJ7',
#  '//bit.ly/18sjXI',
#  '//bit.ly/18xobk',
#  '//bit.ly/3MG0r-',
#  '//bit.ly/69AYs',
#  '//bit.ly/6EW4Q',
#  '//bit.ly/BxdVL',
#  '//bit.ly/H9Nqe',
#  '//bit.ly/HVTHS-',
#  '//bit.ly/KEAy2-',
#  '//bit.ly/NX4aQ',
#  '//bit.ly/Nh82S',
#  '//bit.ly/OnhYd',
#  '//bit.ly/ZoxZC',
#  '//bit.ly/akQLD',
#  '//bit.ly/azFwv',
#  '//bit.ly/cdrcw',
#  '//bit.ly/gXH3q',
#  '//bit.ly/gvMzD',
#  '//bit.ly/mUMFh',
#  '//bit.ly/pXrzV',
#  '//bit.ly/wHLBv',
#  '//bit.ly/wr8Vz',
#  '//blip.fm/~4lfyi',
#  '//blip.fm/~5ytke',
#  '//blip.fm/~5zi9g',
#  '//blip.fm/~6svjq',
#  '//blip.fm/~6tfp6',
#  '//blip.fm/~7d1qo',
#  '//blip.fm/~7d4pk',
#  '//blip.fm/~7g6r0',
#  '//blip.fm/~7qdf0',
#  '//blip.fm/~7s7mn',
#  '//blip.fm/~8k7kl',
#  '//cheezburger.com/tw/',
#  '//is.gd/13be0',
#  '//is.gd/17Eo4',
#  '//is.gd/MRr3',
#  '//loopt.us/PPYZTQ.t',
#  '//migre.me/281e',
#  '//myloc.me/27HX',
#  '//mypict.me/2QIM',
#  '//nascar.com/racebuddy',
#  '//ow.ly/fHJc',
#  '//plurk.com/p/1230lz',
#  '//plurk.com/p/13s5mg',
#  '//plurk.com/p/x8j86',
#  '//plurk.com/p/yq08l',
#  '//sbne.ws/r/vWc',
#  '//tinyurl.com',
#  '//tinyurl.com/b3yobq',
#  '//tinyurl.com/bvagbj',
#  '//tinyurl.com/cbl6tm',
#  '//tinyurl.com/ckbmkc',
#  '//tinyurl.com/dflzg4',
#  '//tinyurl.com/eqbwe',
#  '//tinyurl.com/ljgec2',
#  '//tinyurl.com/m2p6yk',
#  '//tinyurl.com/mbmanohara',
#  '//tinyurl.com/ncqkm5',
#  '//tinyurl.com/ngbq2c',
#  '//tinyurl.com/oropl7',
#  '//tinyurl.com/pd4wyp',
#  '//tr.im/jd0y',
#  '//tr.im/jj70',
#  '//tr.im/khKW',
#  '//tr.im/kmET-',
#  '//tr.im/koFz-',
#  '//tr.im/lAj6',
#  '//tr.im/lCEl',
#  '//tr.im/lvBu',
#  '//tr.im/mLsn-',
#  '//tr.im/mP2j',
#  '//tr.im/mVTm-',
#  '//tr.im/mWKn',
#  '//tr.im/mZ8l',
#  '//tr.im/mZVC',
#  '//tr.im/n18y',
#  '//tr.im/n7J0',
#  '//tr.im/n8AI',
#  '//tr.im/nDkq',
#  '//tr.im/nJOo',
#  '//tr.im/nfKO-',
#  '//tr.im/nhcv',
#  '//tr.im/nyYv',
#  '//tr.im/oBOf',
#  '//tr.im/oERy',
#  '//tr.im/oFLS',
#  '//tr.im/ox5G',
#  '//tr.im/oyT7',
#  '//tumblr.com/x6n25amd5',
#  '//tumblr.com/x9c238auy',
#  '//tumblr.com/xaj24dkly',
#  '//tumblr.com/xcn21w6o7',
#  '//tumblr.com/xfj1uain0',
#  '//tumblr.com/xkh1z19us',
#  '//tumblr.com/xl21pafgm',
#  '//tumblr.com/xpn1wrj48',
#  '//tumblr.com/xqn1x1tue',
#  '//tumblr.com/xr0238tmq',
#  '//tumblr.com/xsg1m3ufn',
#  '//tumblr.com/xv31s2pi8',
#  '//tumblr.com/xvq1mln1l-',
#  '//tumblr.com/xwp1yxhi6',
#  '//tumblr.com/xxw2329lh',
#  '//tumblr.com/xzg1wy4jj',
#  '//tumblr.com/xzp224xgj',
#  '//twitpic.com/6bo0t',
#  '//twitpic.com/6ikhd',
#  '//twitpic.com/6ioi8',
#  '//twitpic.com/6vsv8',
#  '//twitpic.com/75hsg',
#  '//twitpic.com/75kwb',
#  '//twurl.nl/dvu8be',
#  '//u.mavrev.com/bc7v',
#  '//www.dailysportspages.com/forums/showthread.php',
#  '//www.imediaconnection.com/content/23465.asp',
#  '//www.kansas.com/news/featured/story/860875.html',
#  '//www.nhl.com',
#  '//www.twitpic.com/6e3zp',
#  '/em',
#  '06/04/2009',
#  '112-102',
#  '12*23*2007',
#  '12-4',
#  '1280x1024',
#  '1920x1080',
#  '1:30AM',
#  '2.75',
#  '2009..hope',
#  '23k',
#  '2at',
#  '3.14',
#  '4Eva=-',
#  '62.',
#  '62.-',
#  '70-542',
#  '79.75',
#  '9-7/',
#  '902',
#  ':3-',
#  'ACL',
#  'AFI',
#  'APL',
#  'ASSES',
#  'A_',
#  'Aiigght',
#  'Aimee_B_Loved',
#  'Aiqht',
#  'Alllllan',
#  'Ame..',
#  'AtlanticÂ',
#  'Ayonna',
#  'BABBBBBBBBYY',
#  'BOREDDDD',
#  'BYYEEE',
#  'Barber',
#  'Barkley',
#  'Beansummer',
#  'Bebot',
#  'Birdie',
#  'Blase',
#  'BoRinG',
#  'Boyfie',
#  'Brussels',
#  'Bungie',
#  'CHP',
#  'COMMING',
#  'CONGRATZ',
#  'CORNELL',
#  'CRy',
#  'Californians',
#  'CandyGirls',
#  'Capitals',
#  'CharlottegC',
#  'Chealea',
#  'Commie',
#  'Commies',
#  'Confirmed',
#  'Content.',
#  'Coroner',
#  'CranberryPerson',
#  'Crashed',
#  'Creativity',
#  'Cried',
#  'Curtain',
#  'DEALS',
#  'DJDolceVita',
#  'DJWiLLGATES',
#  'DREAMIN',
#  'DaPrbmChild',
#  'Daninho502',
#  'Darcy_Lussier',
#  'DarrenSproat',
#  'Dayngr',
#  'Dbl',
#  'DebraWard',
#  'Decode',
#  'DemonicTurtle',
#  'Dies',
#  'Diggâ\x80\x99s',
#  'Dinara',
#  'Diplomatic',
#  'DirtyRose17',
#  'Distracting',
#  'Douchebag',
#  'Drexel',
#  'Drunvalo',
#  'Dunn',
#  'Duo',
#  'ECL',
#  'ELYSIANFIELDZ=CLASS',
#  'ELYSIANFIELDZAJ=NO',
#  'EPICCC',
#  'ERiceOnTheBeat',
#  'Eagles',
#  'Editors',
#  'EightyThreeKid',
#  'Em91',
#  'Entrepreneur',
#  'Eureka',
#  'Euromillions',
#  'Ever..',
#  'EvertB',
#  'Exercise',
#  'ExoticBella_',
#  'Explore',
#  'EzraJane',
#  'F**kn',
#  'F.A',
#  'FIELD',
#  'FINAL',
#  'FRANK',
#  'FU2',
#  'Faltam',
#  'Famed',
#  'Feeeling',
#  'Femmes',
#  'Fightiin',
#  'Finale',
#  'Finland|',
#  'Fr',
#  'Fuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuck',
#  'Fwd',
#  'Fwy',
#  'G.',
#  'GRRRRRRRRREAT',
#  'G_D',
#  'Geek_And_Poke',
#  'Glamicole',
#  'Gnarls',
#  'Gongwer',
#  'Goodbassplayer',
#  'Goodniqht',
#  'GrAdUaTE',
#  'GrRr',
#  'Grac..',
#  'Grahamapalooza',
#  'Guardian',
#  'HIMSELF',
#  'Haley',
#  'Hardest',
#  'HaterMagazine',
#  'Heathers',
#  'Hedo',
#  'Hijack_King7',
#  'Hippo',
#  'HitzProductions',
#  'Hom',
#  'Hospitol',
#  'Humphrey',
#  'Hungover',
#  'Huskies',
#  'IDC',
#  'ILY2',
#  'I_am_delo',
#  'J-dawg',
#  'J/M',
#  'JA',
#  'JLew',
#  'Jamarcusssssss',
#  'JeffersonReid',
#  'Jin',
#  'JuicyJones',
#  'Juuuuuuuuuuuuuuuuussssst',
#  'KarenWild',
#  'KarlKleese',
#  'Karmada',
#  'Keahey',
#  'Kerry350',
#  'Kouture85',
#  'Kristis',
#  'Kyauphie',
#  'LAFD',
#  'LAFD*UPDATE',
#  'LAMMMMEEE',
#  'LAMPARD',
#  'LHSOPERAFIENDS',
#  'LOSING',
#  'LadyKeisha',
#  'Landin',
#  'Leloz',
#  'LisaBarone',
#  'Lizzie.',
#  'Locations',
#  'LostZombies',
#  'LuV',
#  'MCMudkips',
#  'MENTION',
#  'MICHAEL_CASTRO',
#  'MIZZWALKER',
#  'MORREA',
#  'MX310',
#  'MaMii_THiCKNESS',
#  'Malcolm',
#  'Mama_K',
#  'Manuel',
#  'Marshmallows',
#  'Meat',
#  'MelbourneVixens',
#  'Melchizedek.-',
#  'MelodyChase',
#  'Meteorologists',
#  'Mgapmp',
#  'MiSS',
#  'Midsummer',
#  'MightyBoognish',
#  'MissMarian',
#  'Mission=San',
#  'Mizz_Bliz',
#  'Mmmyeahh',
#  'MoneyAceweather',
#  'Mp3Jackson',
#  'MsNovember',
#  'MusicIsMySunshine',
#  'Muslims',
#  'NAI.-',
#  'NCAA',
#  'NFD',
#  'NO1',
#  'NOLA',
#  'Neena',
#  'Netball',
#  'NiCE',
#  'Non-Robsten',
#  'Nutella',
#  'OilIPO',
#  'Omgaga',
#  'Oneshine',
#  'OregonMJW',
#  'PAN1F',
#  'PERFEKTnCHANCE',
#  'PLUSISAPLUS=N',
#  'Paisano',
#  'Paley',
#  'Palmolive',
#  'Phallic',
#  'PhillMason',
#  'Philoscribe',
#  'Pi',
#  'Playhouse',
#  'Pollute',
#  'Pottercast/Lupins/Willows',
#  'PurpleHazeYobi',
#  'Puurfect',
#  'QQing',
#  'RAPPUBLICIST',
#  'RODDICK',
#  'RON_NO4LYFE=WORK',
#  'Raid',
#  'Rained',
#  'Rapture',
#  'Re-Ripped',
#  'Reubens',
#  'Reznor',
#  'Rishabh',
#  'Rob_in_Grantham',
#  'Rollin',
#  'RoniBryantMusic',
#  'Royalty',
#  'Rue',
#  'SHARON',
#  'SHIZ',
#  'SICKNESS',
#  'SLEEPIES',
#  'SMF',
#  'SRenaeNae',
#  'STRES',
#  'STRIKE',
#  'Safina',
#  'Safins',
#  'SandyU',
#  'Savage_Death55',
#  'Scoobs',
#  'Semisonic',
#  'Senator',
#  'Sharboubou',
#  'ShaunAcland',
#  'ShawnaShameless',
#  'ShinyHappyHead',
#  'Shottas',
#  'SirKenRobinson',
#  'Sis-be',
#  'SlashHudson',
#  'Snubbmatic',
#  'SongStuckInMyHeadWhenIWokeUp',
#  'Sooooooooooo',
#  'St*',
#  'Standing_Stones',
#  'StarHubCares',
#  'StephenHDunn',
#  'Supertramp',
#  'Suzumiya',
#  'TDa',
#  'THEDIAMONDCOACH',
#  'TIED',
#  'TWITS',
#  'TWiCE',
#  'Talvez',
#  'Teams',
#  'Tellman',
#  'Tellman-',
#  'TendaiJoe',
#  'Thatsrightnate',
#  'TheIanCrawford',
#  'Thestreetforce',
#  'ThisChicsFlava',
#  'Tigersfan',
#  'Tombre',
#  'Toodles',
#  'Tourny',
#  'Transfer',
#  'TravelTips',
#  'Triiiiiii',
#  'TweetWrath',
#  'Twitterpated',
#  'UGHHHHHHHHHHHHHHHHHHHHHHHHHHHHH',
#  'UVA',
#  'UghH',
#  'Uprizing',
#  'Vandals',
#  'Vibe',
#  'Violent',
#  'Voltron',
#  'WAY+',
#  'WILL+WAY',
#  'WOOTS',
#  'WParenthetical',
#  'Waiit',
#  'Wardrobe',
#  'Waterfalls',
#  'WeeLaura',
#  'Wiit',
#  'Win7RC',
#  'Winona4ever',
#  'Woodpecker',
#  'Wove',
#  'XBLA',
#  'Yuuutsu',
#  'ZOEBOE',
#  'Zahra',
#  '^^-',
#  '_ETJ=',
#  '__cheer',
#  '_rosiecakes',
#  'aChAotIcBeaUtY',
#  'aaronXnow',
#  'account*',
#  'adamisacson',
#  'ahugeproduction',
#  'alarming',
#  'alexrauchman',
#  'all..imma',
#  'alpolitics',
#  'alternatÃ\xadva',
#  'althani96',
#  'ambergirl66',
#  'amor..im',
#  'anoron.reedcourty.operaunite.com/webserver/content/',
#  'anyonefeeling',
#  'anything-anything',
#  'aramex',
#  'arjunbasu',
#  'arre',
#  'arrrrrrrgggggggghhhhhhhh',
#  'artbook',
#  'ass.-',
#  'ast',
#  'atenÃ§Ã£o',
#  'awhhe',
#  'b.b',
#  'back-up',
#  'baddest',
#  'baileygenine',
#  'baithing',
#  'bananarchy_atx',
#  'banten',
#  'batt',
#  'bcd',
#  'beatings',
#  'bedss',
#  'behold~',
#  'benboychuk',
#  'bestttttttttttttttttttt',
#  'betseyjohnson',
#  'bf..I',
#  'bicyclist',
#  'blackswan2',
#  'blankeys',
#  'blingg',
#  'blocker',
#  'blondediva11',
#  'blowdrying',
#  'bogan',
#  'bordeirlne',
#  'boro',
#  'bosco',
#  'bows',
#  'brother..',
#  'bsideofSoccer-',
#  'bubu',
#  'bugaboo',
#  'burgerS',
#  'burswood',
#  'buu',
#  'caio',
#  'call..not',
#  'canaveral',
#  'cancelledd',
#  'canuckgrrrl',
#  'cat.',
#  'cate',
#  'celulite',
#  'certification',
#  'chastity_1111',
#  'cheeSe',
#  'cheeseburglar',
#  'chicago..b',
#  'cifra',
#  'circustk',
#  'clashes',
#  'clocking',
#  'cmedders',
#  'colostomy',
#  'comprehend',
#  'coop',
#  'cousinnn',
#  'cram',
#  'craper',
#  'crewislife',
#  'cried.-',
#  'cristinerafae',
#  'cybervenus',
#  'daley',
#  'damienrandle',
#  'danawalker',
#  'dandelionas',
#  'dannyvan',
#  'danregal',
#  'dark..',
#  'daveena',
#  'dcist',
#  'deactivate',
#  'deathbed',
#  'deathmatch',
#  'dentists',
#  'designrelated',
#  'desiredeffect',
#  'devstateddd',
#  'dinger',
#  'dinner..sigh..',
#  'dishwashing',
#  'do-er',
#  'donutspy',
#  'doodle',
#  'dreamingspires',
#  'drills',
#  'dustincary',
#  'dyck',
#  'e-hugs*',
#  'elect',
#  'electrograffiti',
#  'elise',
#  'em*',
#  'emilymariie',
#  'employ',
#  'emusic',
#  'essentially_me',
#  'estimates',
#  'eveer',
#  'facebook.com/copic.marker',
#  'famliy',
#  'fartâ\x80',
#  'fb-',
#  'fcukk',
#  'fernandofelman',
#  'fettucini',
#  'fifty',
#  'fifty..',
#  'finally..random',
#  'fixed..ca',
#  'fl..',
#  'flopearedmule',
#  'fonebook',
#  'fontenot619',
#  'footwear',
#  'foreverr',
#  'frownies',
#  'fucccckkkkkkkkkk',
#  'gayyyy',
#  'gelatin',
#  'georgediaz',
#  'gerald',
#  'gigi4462',
#  'gigia',
#  'ginaaa',
#  'giveway',
#  'gone*',
#  'good..wish',
#  'goodnight..',
#  'grateful-',
#  'grindin',
#  'gutterd',
#  'h..',
#  'hannahradford',
#  'hapnin',
#  'happy-',
#  'haterade',
#  'haugern',
#  'hawaiibuzz',
#  'helio',
#  'hellopnsdear',
#  'hidingesther',
#  'hiim',
#  'hilarious-',
#  'hippojuicefilm',
#  'historian',
#  'hitech',
#  'holleR',
#  'home.sch',
#  'homee',
#  'homeless/creeps',
#  'homers',
#  'hores',
#  'horsie',
#  'howlieT',
#  'hummer',
#  'hunger-related',
#  'huu',
#  'huz',
#  'iamfauxpas',
#  'iamyas',
#  'idvssuperego',
#  'iggigg',
#  'ignorantsheep*',
#  'iluvTerricka',
#  'ilysfm',
#  'incorporate',
#  'infobotz',
#  'innnnn.',
#  'intrusion',
#  'iphonegiveway',
#  'irissa',
#  'is.-',
#  'is..and',
#  'isak',
#  'itttttt=-',
#  'ius',
#  'ivegotzooms',
#  'jam*',
#  'jazzgotsoul',
#  'jerrybattiste',
#  'joaoqalves',
#  'jodie',
#  'joecopas2671',
#  'joeschmitt',
#  'joetech',
#  'johnmaeda',
#  'johnnybeane',
#  'jonswerens',
#  'joseke',
#  'jubii',
#  'jurgenphoto',
#  'kaitymarine',
#  'kandie',
#  'kashrut',
#  'katherineholden',
#  'katiedontcry',
#  'kcome',
#  'kezbat',
#  'khead',
#  'kid.-',
#  'killavilla',
#  'kittyireland',
#  'klitoria',
#  'kosherFAIL',
#  'ksymmonds',
#  'kvetchingeditor',
#  'labeling',
#  'latuacatante17',
#  'laughter*',
#  'lazoug',
#  'lazzzzyyyy',
#  'lea..',
#  'leafy',
#  'leysh',
#  'libraritarian59',
#  'lifeeee.',
#  'linininiooh',
#  'liquid.',
#  'lisad',
#  'little.',
#  'lkrammes',
#  'loic',
#  'loin',
#  'lolife4life',
#  'lorinimus',
#  'loviie',
#  'lowridergrl',
#  'lpjdesign',
#  'lufflies',
#  'lushhh',
#  'lushone',
#  'luvly',
#  'masareus',
#  'mathces',
#  'meganmcdowell',
#  'mgph3nom',
#  'michaelsarver',
#  'mikehanes',
#  'mimbles',
#  'minghao',
#  'minimizes',
#  'misterdjin',
#  'mlia',
#  'mmmaybe',
#  'mom-',
#  'momacita',
#  'mondayeyes',
#  'money..ca',
#  'moneybagzfam1st',
#  'monique4ever',
#  'moogyboobles',
#  'motions',
#  'mourn',
#  'mousey',
#  'moval',
#  'mowin',
#  'mrjoecool',
#  'mxit',
#  'my.TC',
#  'mysapce',
#  'n3rin3',
#  'napp',
#  'nebody',
#  'nehabagoria',
#  'netfart',
#  'nibaq',
#  'niggahz',
#  'nikkofelipe',
#  'nodaji',
#  'nodding',
#  'normaltusker',
#  'oVe',
#  'octo',
#  'ohhushaubrey',
#  'oliveshoot',
#  'oneâ\x80\x99s',
#  'ood',
#  'opposite-',
#  'oreos..',
#  'overanalyzing',
#  'overdosed',
#  'p1wimax',
#  'paints',
#  'paper-',
#  'paraguay',
#  'path-',
#  'pavel',
#  'peOplE',
#  'pfont',
#  'pinkeye',
#  'pinkraygun',
#  'pixma',
#  'plc',
#  'plmusic22-',
#  'poemsunder140',
#  'position*',
#  'postcards/mailers',
#  'potted',
#  'powershot',
#  'prblog',
#  'properly..',
#  'quilting',
#  'quizzage',
#  'quorn..',
#  'r0ckrulez',
#  'raybooysen',
#  're-model-ing',
#  'reaallly',
#  'really2',
#  'realms',
#  'release..',
#  'relievers',
#  'riceuniversiity',
#  'richietachie',
#  'rickswift',
#  'rinitis',
#  'robi27',
#  'rooooooooomies',
#  'roughplaces',
#  'rupturerapture',
#  'rur',
#  's400',
#  'sadpanda',
#  'said*',
#  'sannesias',
#  'saveohiolibraries',
#  'scene.One',
#  'scheming',
#  'scolding',
#  'seashore',
#  'seja',
#  'serialseb',
#  'sf_giants',
#  'shaneaddinall',
#  'shannonelyse1',
#  'sharpie',
#  'shaunamanu',
#  'side.its',
#  'sleeping..aahh.-',
#  'slope..and',
#  'smiling.-',
#  'sommacolada',
#  'son-of-a-b*tch',
#  'sos',
#  'soultravelers3',
#  'soundly',
#  'sozi1',
#  'squared',
#  'squaresp',
#  'squarespac',
#  'squarespce',
#  'squeezes',
#  'started*',
#  'stated',
#  'steverubel',
#  'stevijean',
#  'stitched',
#  'stress..',
#  'suck.-',
#  'sucksssssss',
#  'summerblonde83',
#  'suposed',
#  'swastikas',
#  'sweetlilmzmia',
#  'sylvanus',
#  't9ar5',
#  't=49343',
#  'taKE',
#  'tahninial',
#  'talk-er',
#  'tattood1',
#  'taylorrhicks',
#  'technotetris',
#  'teke',
#  'texts..',
#  'the_prodigy',
#  'theenglishmuse',
#  'thelovelybones',
#  'then-',
#  'therealglambert',
#  'thesmartmama',
#  'think..becuz',
#  'throwbie',
#  'ticket..I',
#  'ticketsandpassports',
#  'timessss',
#  'timing-',
#  'tmmcwilliams',
#  'today.-',
#  'today..booo',
#  'todaÑ\x87',
#  'toher',
#  "tok'ra",
#  'tomorrow..and',
#  'too..RIP',
#  'toolio',
#  'tortured',
#  'tour..',
#  'trabalhosujo',
#  'trae',
#  'trams',
#  'ughhh..',
#  'undies',
#  'uof',
#  'user-focused',
#  'v7-20659',
#  'va_songstress',
#  'vale',
#  'voltron',
#  'voltrons',
#  'w/cream',
#  'w/oven',
#  'waahhh',
#  'wailing',
#  'wall..Math',
#  'wallet.',
#  'want..',
#  'wantt',
#  'warbo',
#  'ways.',
#  'weeeekend',
#  'weekend..',
#  'weeknd..',
#  'weselec',
#  'whatï¿½s',
#  'while.I',
#  'will.-',
#  'wills',
#  'wishes..',
#  'wo..',
#  'wo/anti-tip',
#  'wo/oven',
#  'wompp',
#  'wompppp',
#  'wwe',
#  'www.apple.com/iphone',
#  'xxkirahxx',
#  'y/o',
#  'yeahuhh',
#  'yeeeeeeeeeeeessshhhh',
#  'yle.fi',
#  'zazzle',
#  'zeldman',
#  'zheyamada',
#  'zochula',
#  'zoro',
#  '~CMF',
#  'Ãªnfase',
#  'Ñ\x87',
#  'à¸\x94à¸¹à¹',
#  'à¸\x9aà¹\x84à¸\x95à¹\x8b',
#  'â\x80\x9cwarm',
#  'â\x80¦',
#  'â\x80¦donâ\x80\x99t',
#  'ï¿½89']

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
def stem_tokenize(text):
    stemmer = SnowballStemmer("english")
    stemmer = WordNetLemmatizer()
    return [stemmer.lemmatize(token) for token in word_tokenize(text)]

def lemmatize_tokenize(text):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline

# %%
class TextPreProc(BaseEstimator,TransformerMixin):
    def __init__(self, use_mention=False):
        self.use_mention = use_mention
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        # We can choose between keeping the mentions
        # or deleting them
        if self.use_mention:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", " @tags ")
        else:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", "")
            
        # Keeping only the word after the #
        X = X.str.replace("#", "")
        X = X.str.replace(r"[-\.\n]", "")
        # Removing HTML garbage
        X = X.str.replace(r"&\w+;", "")
        # Removing links
        X = X.str.replace(r"https?://\S*", "")
        # replace repeated letters with only two occurences
        # heeeelllloooo => heelloo
        X = X.str.replace(r"(.)\1+", r"\1\1")
        # mark emoticons as happy or sad
        X = X.str.replace(HAPPY_EMO, " happyemoticons ")
        X = X.str.replace(SAD_EMO, " sademoticons ")
        X = X.str.lower()
        return X

# %%
from sklearn.model_selection import train_test_split

sentiments = train_twitter['Sentiment']
tweets = train_twitter['SentimentText']


vectorizer = TfidfVectorizer(tokenizer=lemmatize_tokenize, ngram_range=(1,2))
pipeline = Pipeline([
    ('text_pre_processing', TextPreProc(use_mention=True)),
    ('vectorizer', vectorizer),
])

# Let's split our data into learning set and testing set
# This process is done to test the efficency of our model at the end.
# You shouldn't look at the test data only after choosing the final model
learn_data, test_data, sentiments_learning, sentiments_test = train_test_split(tweets, sentiments, test_size=0.3)

# This will tranform our learning data from simple text to vector
# by going through the preprocessing tranformer.
learning_data = pipeline.fit_transform(learn_data)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

lr = LogisticRegression()
bnb = BernoulliNB()
mnb = MultinomialNB()

models = {
    'logitic regression': lr,
    'bernoulliNB': bnb,
    'multinomialNB': mnb,
}

for model in models.keys():
    scores = cross_val_score(models[model], learning_data, sentiments_learning, scoring="f1", cv=10)
    print("===", model, "===")
    print("scores = ", scores)
    print("mean = ", scores.mean())
    print("variance = ", scores.var())
    models[model].fit(learning_data, sentiments_learning)
    print("score on the learning data (accuracy) = ", accuracy_score(models[model].predict(learning_data), sentiments_learning))
    print("")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# === logitic regression ===
# scores =  [0.80464497 0.8147343  0.81830319 0.81278649 0.80465906 0.80911612
#  0.81063523 0.81047019 0.81627739 0.81460203]
# mean =  0.8116228980528837
# variance =  1.919752207161362e-05
# score on the learning data (accuracy) =  0.8717567722025374
#
# === bernoulliNB ===
# scores =  [0.77790807 0.78784309 0.79119586 0.78668224 0.78573942 0.7883074
#  0.78457043 0.78796427 0.79365079 0.78766725]
# mean =  0.7871528814232763
# variance =  1.5565578582550777e-05
# score on the learning data (accuracy) =  0.9018602125957252
#
# === multinomialNB ===
# scores =  [0.80826942 0.81062899 0.81445029 0.81019704 0.80534521 0.80423398
#  0.80770945 0.80353547 0.81197818 0.81037349]
# mean =  0.8086721521286583
# variance =  1.1160611579688293e-05
# score on the learning data (accuracy) =  0.9001600182878043

# %%
from sklearn.model_selection import GridSearchCV

grid_search_pipeline = Pipeline([
    ('text_pre_processing', TextPreProc()),
    ('vectorizer', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

params = [
    {
        'text_pre_processing__use_mention': [True, False],
        'vectorizer__max_features': [1000, 2000, 5000, 10000, 20000, None],
        'vectorizer__ngram_range': [(1,1), (1,2)],
    },
]
grid_search = GridSearchCV(grid_search_pipeline, params, cv=5, scoring='f1')
grid_search.fit(learn_data, sentiments_learning)
print(grid_search.best_params_)
# Out:
# {'text_pre_processing__use_mention': True, 'vectorizer__max_features': None, 'vectorizer__ngram_range': (1, 2)}

# %%
mnb.fit(learning_data, sentiments_learning)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
testing_data = pipeline.transform(test_data)
mnb.score(testing_data, sentiments_test)
# Out:
# 0.7575090842417576

# %%
# Just run it
model = MultinomialNB()
model.fit(learning_data, sentiments_learning)
tweet = pd.Series([input(),])
tweet = pipeline.transform(tweet)
proba = model.predict_proba(tweet)[0]
print("The probability that this tweet is sad is:", proba[0])
print("The probability that this tweet is happy is:", proba[1])
# Out:
# I lost my wallet
# The probability that this tweet is sad is: 0.9071442218823456
# The probability that this tweet is happy is: 0.09285577811765514
